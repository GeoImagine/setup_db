# %% [markdown]
# # GeoImagine Setup Database
#
# ## Goal: Setup the GeoImagine PostgreSQL database.
#
# ## Required installations:
# - Anaconda
# - PostgreSQL (on MacOS use e.g. Homebrew [brew install postgresql@15])
# - Jupyter Notebook environment (e.g. Visual Studio Code [VScode])
#
# ## Recommended installation:
# - PosgreSQL grapical interface [e.g. TablePlus]
#
# ## Conda virtual environment
#
# To run the notebook you have to install the virtual conda environment. You can find the environment (yml) file in the GitHub repository:

# %%
# Standard library imports
from os import path
# Third party imports
from base64 import b64encode
import netrc
# Local imports
from setup_db_class import PGsession

# %% [markdown]
# ## Def DbConnect

# %%
def DbConnect(db):
    '''
    '''
    # the HOST must exist in the .netrc file in the users home directory
    HOST = 'karttur'
    # Retrieve login and password from the .netrc file
    secrets = netrc.netrc()
    # Authenticate username, account and password 
    username, account, password = secrets.authenticators( HOST )
    # Encode the password before sending it
    password = b64encode(password.encode())
    # Create a query dictionary for connecting to the Postgres server  
    query = {'db':db, 'user':username, 'pswd':password}
    return query

# %% [markdown]
# ## Def SetUpProdDb

# %%
def SetUpProdDb(prodDB):
    '''
    Create production database (db)
    '''
    # Get the user and password for connecting to the db, login to the default cluster postgres
    query = DbConnect('postgres')
    # Connect to the Postgres Server
    iniSession = PGsession(query)
    # Set the name of your production database( db)
    prodDbD = {'dbname':prodDB}
    # Select the current (cluster) db
    iniSession.cursor.execute("SELECT current_database()")
    # Get the results from the SELECT statement
    record = iniSession.cursor.fetchone()
    # Print Current (cluster) db
    print ('    Current database', record[0])
    # Select the logged in user
    iniSession.cursor.execute("SELECT user")
    # Get the results from the SELECT statement
    record = iniSession.cursor.fetchone()
    # Print Current user
    print ('    User', record[0])
    # Select all databases in the cluster db
    iniSession.cursor.execute("SELECT datname FROM pg_database;")
    # Get the results from the SELECT statement
    records = iniSession.cursor.fetchall()
    # Convert the retrieved records to a simple list
    dbL = [item[0] for item in records]
    # Print the list of all databases in the cluster
    print ('    Databases', dbL)
    # Check if your required production db is in the list
    if not prodDbD['dbname'] in dbL:
        # The requested production db does not exists
        printstr = '    Creating database: %s' %( prodDbD['dbname'])
        #Import the psycopg extension that allows you to create a new db
        from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
        #Invoke the connection with the extension
        iniSession.conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)
        #Create your production db
        iniSession.cursor.execute("CREATE DATABASE %(dbname)s;" %prodDbD)
    else:
        # The requested production db already exists
        printstr = '    Database %s already exists' %( prodDbD['dbname'])
    # Print the result
    printstr = '    Database %s already exists' %( prodDB)
    print (printstr)

# %% [markdown]
# ## def SetupSchemasTables

# %%
def SetupSchemasTables(projFPN,db):
    '''
    Setup schemas and tables
    '''   
    # Get the full path to the project text file
    dirPath = path.split(projFPN)[0]
    # Open and read the text file linking to all json files defining the project
    with open(projFPN) as f:
        jsonL = f.readlines()
    # Clean the list of json objects from comments and whithespace etc    
    jsonL = [path.join(dirPath,x.strip())  for x in jsonL if len(x) > 10 and x[0] != '#']
    # Get the user and password for connecting to the db
    query = DbConnect(db)
    # Connect to the Postgres Server
    session = PGsession(query)
    # Loop over all json files and create Schemas and Tables
    for jsonObj in jsonL:
        print ('    jsonObj',jsonObj)
        session.ReadRunJson(jsonObj)
    # Close the db connection   
    session._Close()

# %% [markdown]
# ## Main

# %%
if __name__ == "__main__":
    '''
    This module should only be run at the very startup of building the Karttur GeoImagine framework.
    To run, remove the comment "#prodDB" and set the name of your production DB ("YourProdDB")
    ''' 
    # Set the name of the productions db cluster
    # prodDB = 'YourProdDB' #'e.g. postgres or geoimagine
    prodDB = 'geoimagine'
    '''
    SetUpProdDb creates an empty Postgres database.
    '''
    SetUpProdDb(prodDB)
    '''
    SetupSchemasTables creates schemas and tables from json files, with the relative path to the
    json files given in the plain text file "projFPN".
    '''
    projFPN = path.join('doc','db_karttur_setup_20211018.txt')
    SetupSchemasTables(projFPN,prodDB)
# Out:
# conn_string host='localhost' dbname='postgres' user='karttur' password='weg-iK8-tng-w9k'
#     Current database postgres
#     User karttur
#     Databases ['postgres', 'template1', 'template0', 'geoimagine']
#     Database geoimagine already exists
# conn_string host='localhost' dbname='geoimagine' user='karttur' password='weg-iK8-tng-w9k'
#     jsonObj doc/jsonsql/general_schema_v090_sql.json
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203170>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103bd4140>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103bd4110>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'process';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203260>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203200>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203230>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'ancillary';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203320>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x1042032c0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x1042032f0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'system';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x1042033e0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203380>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x1042033b0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'regions';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x1042034d0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203440>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x1042034a0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'landsat';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203740>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203530>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203650>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'sentinel';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x1042037d0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203590>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x1042037a0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'modis';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203890>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203830>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203860>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'userlocale';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203950>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x1042038f0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203920>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'specimen';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203a10>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x1042039b0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x1042039e0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'topography';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203ad0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203a70>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203aa0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'layout';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203b90>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203b30>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203b60>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'export';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203c50>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203bf0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203c20>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'soilmoisture';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203d10>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203cb0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203ce0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'smap';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203dd0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203d70>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203da0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'modispolar';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203e90>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203e30>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203e60>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'ease2n';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203f50>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203ef0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203f20>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'ease2s';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104220050>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203fb0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203fe0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'ease2t';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104220110>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x1042200b0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x1042200e0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'climateindex';
#     jsonObj doc/jsonsql/general_processes_v090_sql.json
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x1042207d0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104220770>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x1042207a0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'process' AND table_name = 'rootprocesses');
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104220890>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104220830>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104220860>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'process' AND table_name = 'subprocesses');
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104220950>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x1042208f0>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104220920>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'process' AND table_name = 'procdiv');
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104220a10>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x1042209b0>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x1042209e0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'process' AND table_name = 'procsys');
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104220ad0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104220a70>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104220aa0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'process' AND table_name = 'processparams');
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104220b90>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104220b30>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104220b60>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'process' AND table_name = 'processparamsetvalues');
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104220c50>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104220bf0>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104220c20>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'process' AND table_name = 'processparamsetminmax');
#     jsonObj doc/jsonsql/SMAP_v090_sql.json
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203920>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x1042038c0>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203950>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'smap' AND table_name = 'daacholdings');
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x1042039e0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104202e40>,
#  'processid': 'tableinsert',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203a10>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT * FROM smap.daacholdings WHERE daacid = 'SPL2SMA' AND version = 3;
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203ad0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104202f60>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203a40>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'smap' AND table_name = 'daacdata');
#     jsonObj doc/jsonsql/modis_daacdata_v090_sql.json
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104203bc0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': True,
#  'parameters': <setup_db_class.Struct object at 0x104203b00>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203d10>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'modis' AND table_name = 'daacdata');
#      DROP TABLE modis.daacdata;
#      CREATE TABLE modis.daacdata ( daacid varchar(64),version character(3),tileid character(26),filename character varying(128),htile smallint,vtile smallint,hvtile char(6),acqdate date,doy smallint,downloaded character(1) DEFAULT 'N',organized character(1) DEFAULT 'N',exploded character(1) DEFAULT 'N',redundant character(1) DEFAULT 'N',deleted character(1) DEFAULT 'N',maskstatus character(1) DEFAULT 'Y',PRIMARY KEY (filename) );
#     process parameters:
# {'acceptmissing': True,
#  'delete': True,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x104202f30>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x104203d40>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x104203dd0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'modis' AND table_name = 'tiles');
#      DROP TABLE modis.tiles;

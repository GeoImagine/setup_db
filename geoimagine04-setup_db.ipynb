# %% [markdown]
# # GeoImagine Setup Database
#
# ## Goal: Setup the GeoImagine PostgreSQL database.
#
# ## Required installations:
# - Anaconda
# - PostgreSQL (on MacOS use e.g. Homebrew [brew install postgresql@15])
# - Jupyter Notebook environment (e.g. Visual Studio Code [VScode])
#
# ## Recommended installation:
# - PosgreSQL grapical interface [e.g. TablePlus]
#
# ## Conda virtual environment
#
# To run the notebook you have to install the virtual conda environment. You can find the environment (yml) file in the GitHub repository:

# %%
# Standard library imports
from os import path
# Third party imports
from base64 import b64encode
import netrc
# Local imports
from setup_db_class import PGsession

# %% [markdown]
# ## Def DbConnect

# %%
def DbConnect(db):
    '''
    '''
    # the HOST must exist in the .netrc file in the users home directory
    HOST = 'karttur'
    # Retrieve login and password from the .netrc file
    secrets = netrc.netrc()
    # Authenticate username, account and password 
    username, account, password = secrets.authenticators( HOST )
    # Encode the password before sending it
    password = b64encode(password.encode())
    # Create a query dictionary for connecting to the Postgres server  
    query = {'db':db, 'user':username, 'pswd':password}
    return query

# %% [markdown]
# ## Def SetUpProdDb

# %%
def SetUpProdDb(prodDB):
    '''
    Create production database (db)
    '''
    # Get the user and password for connecting to the db, login to the default cluster postgres
    query = DbConnect('postgres')
    # Connect to the Postgres Server
    iniSession = PGsession(query)
    # Set the name of your production database( db)
    prodDbD = {'dbname':prodDB}
    # Select the current (cluster) db
    iniSession.cursor.execute("SELECT current_database()")
    # Get the results from the SELECT statement
    record = iniSession.cursor.fetchone()
    # Print Current (cluster) db
    print ('    Current database', record[0])
    # Select the logged in user
    iniSession.cursor.execute("SELECT user")
    # Get the results from the SELECT statement
    record = iniSession.cursor.fetchone()
    # Print Current user
    print ('    User', record[0])
    # Select all databases in the cluster db
    iniSession.cursor.execute("SELECT datname FROM pg_database;")
    # Get the results from the SELECT statement
    records = iniSession.cursor.fetchall()
    # Convert the retrieved records to a simple list
    dbL = [item[0] for item in records]
    # Print the list of all databases in the cluster
    print ('    Databases', dbL)
    # Check if your required production db is in the list
    if not prodDbD['dbname'] in dbL:
        # The requested production db does not exists
        printstr = '    Creating database: %s' %( prodDbD['dbname'])
        #Import the psycopg extension that allows you to create a new db
        from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
        #Invoke the connection with the extension
        iniSession.conn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)
        #Create your production db
        iniSession.cursor.execute("CREATE DATABASE %(dbname)s;" %prodDbD)
    else:
        # The requested production db already exists
        printstr = '    Database %s already exists' %( prodDbD['dbname'])
    # Print the result
    printstr = '    Database %s already exists' %( prodDB)
    print (printstr)

# %% [markdown]
# ## def SetupSchemasTables

# %%
def SetupSchemasTables(projFPN,db):
    '''
    Setup schemas and tables
    '''   
    # Get the full path to the project text file
    dirPath = path.split(projFPN)[0]
    # Open and read the text file linking to all json files defining the project
    with open(projFPN) as f:
        jsonL = f.readlines()
    # Clean the list of json objects from comments and whithespace etc    
    jsonL = [path.join(dirPath,x.strip())  for x in jsonL if len(x) > 10 and x[0] != '#']
    # Get the user and password for connecting to the db
    query = DbConnect(db)
    # Connect to the Postgres Server
    session = PGsession(query)
    # Loop over all json files and create Schemas and Tables
    for jsonObj in jsonL:
        print ('    jsonObj',jsonObj)
        session.ReadRunJson(jsonObj)
    # Close the db connection   
    session._Close()

# %% [markdown]
# ## Main

# %%
if __name__ == "__main__":
    '''
    This module should only be run at the very startup of building the Karttur GeoImagine framework.
    To run, remove the comment "#prodDB" and set the name of your production DB ("YourProdDB")
    ''' 
    # Set the name of the productions db cluster
    # prodDB = 'YourProdDB' #'e.g. postgres or geoimagine
    prodDB = 'geoimagine'
    '''
    SetUpProdDb creates an empty Postgres database.
    '''
    SetUpProdDb(prodDB)
    '''
    SetupSchemasTables creates schemas and tables from json files, with the relative path to the
    json files given in the plain text file "projFPN".
    '''
    projFPN = path.join('doc','db_karttur_setup_20211018.txt')
    SetupSchemasTables(projFPN,prodDB)
# Out:
# conn_string host='localhost' dbname='postgres' user='karttur' password='weg-iK8-tng-w9k'
#     Current database postgres
#     User karttur
#     Databases ['postgres', 'template1', 'template0', 'geoimagine']
#     Database geoimagine already exists
# conn_string host='localhost' dbname='geoimagine' user='karttur' password='weg-iK8-tng-w9k'
#     jsonObj doc/jsonsql/general_schema_v090_sql.json
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6a6f0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6a6c0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103dd6ab0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'process';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6a7b0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6a750>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6a780>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'ancillary';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6a990>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6a840>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6a870>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'system';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6aa80>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6a8a0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6a8d0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'regions';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6ab40>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6aae0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6ab10>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'landsat';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6ac00>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6aba0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6abd0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'sentinel';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6acc0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6ac60>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6ac90>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'modis';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6ad80>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6ad20>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6ad50>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'userlocale';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6ae40>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6ade0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6ae10>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'specimen';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6af00>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6aea0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6aed0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'topography';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6afc0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6af60>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6af90>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'layout';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6b080>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6b020>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6b050>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'export';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6b140>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6b0e0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6b110>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'soilmoisture';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6b200>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6b1a0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6b1d0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'smap';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6b2c0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6b260>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6b290>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'modispolar';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6b380>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6b320>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6b350>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'ease2n';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6b440>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6b3e0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6b410>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'ease2s';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6b500>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6b4a0>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6b4d0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'ease2t';
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6b5c0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6b560>,
#  'processid': 'createschema',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6b590>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT schema_name FROM information_schema.schemata WHERE schema_name = 'climateindex';
#     jsonObj doc/jsonsql/general_processes_v090_sql.json
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6bd10>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6bc80>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6bce0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'process' AND table_name = 'rootprocesses');
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6bdd0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6bd70>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6bda0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'process' AND table_name = 'subprocesses');
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6be90>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6be30>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6be60>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'process' AND table_name = 'procdiv');
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6bf50>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6bef0>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6bf20>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'process' AND table_name = 'procsys');
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f8c050>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6bfb0>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6bfe0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'process' AND table_name = 'processparams');
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f8c110>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f8c0b0>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f8c0e0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'process' AND table_name = 'processparamsetvalues');
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f8c1d0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f8c170>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f8c1a0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'process' AND table_name = 'processparamsetminmax');
#     jsonObj doc/jsonsql/SMAP_v090_sql.json
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6ac30>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6aba0>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6a960>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'smap' AND table_name = 'daacholdings');
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f699a0>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6ac90>,
#  'processid': 'tableinsert',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f699d0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT * FROM smap.daacholdings WHERE daacid = 'SPL2SMA' AND version = 3;
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6ad20>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6ad80>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6ad50>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'smap' AND table_name = 'daacdata');
#     jsonObj doc/jsonsql/modis_daacdata_v090_sql.json
#     process parameters:
# {'acceptmissing': True,
#  'delete': False,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6ba70>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': True,
#  'parameters': <setup_db_class.Struct object at 0x103f6b920>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6a150>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'modis' AND table_name = 'daacdata');
#      DROP TABLE modis.daacdata;
#      CREATE TABLE modis.daacdata ( daacid varchar(64),version character(3),tileid character(26),filename character varying(128),htile smallint,vtile smallint,hvtile char(6),acqdate date,doy smallint,downloaded character(1) DEFAULT 'N',organized character(1) DEFAULT 'N',exploded character(1) DEFAULT 'N',redundant character(1) DEFAULT 'N',deleted character(1) DEFAULT 'N',maskstatus character(1) DEFAULT 'Y',PRIMARY KEY (filename) );
#     process parameters:
# {'acceptmissing': True,
#  'delete': True,
#  'dryrun': False,
#  'dstpath': <setup_db_class.Struct object at 0x103f6be90>,
#  'gdalpath': '/Library/Frameworks/GDAL.framework/Programs',
#  'inkscapepath': '/Applications/Inkscape.app/Contents/MacOS/inkscape',
#  'overwrite': False,
#  'parameters': <setup_db_class.Struct object at 0x103f6a1e0>,
#  'processid': 'createtable',
#  'sagapath': '',
#  'srcpath': <setup_db_class.Struct object at 0x103f6baa0>,
#  'verbose': 2,
#  'wgetpath': '/usr/local/bin'}
#      SELECT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_schema = 'modis' AND table_name = 'tiles');
#      CREATE TABLE modis.tiles ( tileid character(26),tilefilename character varying(128),source character varying(32),product varchar(24),version character(3),acqdate date,doy smallint,folder varchar(16) DEFAULT 'original',downloaded character(1) DEFAULT 'N',organized character(1) DEFAULT 'N',exploded character(1) DEFAULT 'N',redundant character(1) DEFAULT 'N',deleted character(1) DEFAULT 'N',maskstatus character(1) DEFAULT 'N',htile integer,vtile integer,PRIMARY KEY (tileid,product,version) );
